# %%
import nltk

nltk.download('punkt')
nltk.download('stopwords')
nltk.download('wordnet')
nltk.download('omw-1.4')
# Out:
# [nltk_data] Downloading package punkt to
# [nltk_data]     C:\Users\HP\AppData\Roaming\nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# [nltk_data] Downloading package stopwords to
# [nltk_data]     C:\Users\HP\AppData\Roaming\nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!
# [nltk_data] Downloading package wordnet to
# [nltk_data]     C:\Users\HP\AppData\Roaming\nltk_data...
# [nltk_data]   Package wordnet is already up-to-date!
# [nltk_data] Downloading package omw-1.4 to
# [nltk_data]     C:\Users\HP\AppData\Roaming\nltk_data...
# [nltk_data]   Package omw-1.4 is already up-to-date!
# True

# %%
text = """
HELLO Everyone!!! 😊

My name is Misbah Khan and I am learning Natural Language Processing (NLP) in 2026.

I LOVE Machine Learning, Machine Learning, MACHINE LEARNING!!!

You can contact me at misbah123@gmail.com

Visit https://www.openai.com for more information.

I have completed 5 projects and scored 95% in Deep Learning.

The cats are running, jumping and playing happily in the gardens.
"""

# %%
# convert to lowercase 
text = text.lower()
print(text)
# Out:
# hello everyone!!! 😊
#
# my name is misbah khan and i am learning natural language processing (nlp) in 2026.
#
# i love machine learning, machine learning, machine learning!!!
#
# you can contact me at misbah123@gmail.com
#
# visit  for more information.
#
# i have completed 5 projects and scored 95% in deep learning.
#
# the cats are running, jumping and playing happily in the gardens.

# %%
import re

text = re.sub(r'http\S+', '', text)

print(text)
# Out:
# hello everyone!!! 😊
#
# my name is misbah khan and i am learning natural language processing (nlp) in 2026.
#
# i love machine learning, machine learning, machine learning!!!
#
# you can contact me at misbah123@gmail.com
#
# visit  for more information.
#
# i have completed 5 projects and scored 95% in deep learning.
#
# the cats are running, jumping and playing happily in the gardens.

# %%
# Email Removed 
text = re.sub(r'\S+@\S+', '', text)

print(text)
# Out:
# hello everyone!!! 😊
#
# my name is misbah khan and i am learning natural language processing (nlp) in 2026.
#
# i love machine learning, machine learning, machine learning!!!
#
# you can contact me at
#
# visit  for more information.
#
# i have completed 5 projects and scored 95% in deep learning.
#
# the cats are running, jumping and playing happily in the gardens.

# %%
# punctuation removed
import string

text = text.translate(
    str.maketrans('', '', string.punctuation)
)

print(text)
# Out:
# hello everyone 😊
#
# my name is misbah khan and i am learning natural language processing nlp in 2026
#
# i love machine learning machine learning machine learning
#
# you can contact me at
#
# visit  for more information
#
# i have completed 5 projects and scored 95 in deep learning
#
# the cats are running jumping and playing happily in the gardens

# %%
# numbers removed
text = re.sub(r'\d+', '', text)

print(text)
# Out:
# hello everyone 😊
#
# my name is misbah khan and i am learning natural language processing nlp in
#
# i love machine learning machine learning machine learning
#
# you can contact me at
#
# visit  for more information
#
# i have completed  projects and scored  in deep learning
#
# the cats are running jumping and playing happily in the gardens

# %%
# remove extra spaces
text = re.sub(r'\d+', '', text)

print(text)
# Out:
# hello everyone 😊
#
# my name is misbah khan and i am learning natural language processing nlp in
#
# i love machine learning machine learning machine learning
#
# you can contact me at
#
# visit  for more information
#
# i have completed  projects and scored  in deep learning
#
# the cats are running jumping and playing happily in the gardens

# %%
# Tokenization
from nltk.tokenize import word_tokenize

tokens = word_tokenize(text)

print(tokens)
# Out:
# ['hello', 'everyone', '😊', 'my', 'name', 'is', 'misbah', 'khan', 'and', 'i', 'am', 'learning', 'natural', 'language', 'processing', 'nlp', 'in', 'i', 'love', 'machine', 'learning', 'machine', 'learning', 'machine', 'learning', 'you', 'can', 'contact', 'me', 'at', 'visit', 'for', 'more', 'information', 'i', 'have', 'completed', 'projects', 'and', 'scored', 'in', 'deep', 'learning', 'the', 'cats', 'are', 'running', 'jumping', 'and', 'playing', 'happily', 'in', 'the', 'gardens']

# %%
# remove stop words 
from nltk.corpus import stopwords

stop_words = set(stopwords.words('english'))

filtered_words = []

for word in tokens:
    if word not in stop_words:
        filtered_words.append(word)

print(filtered_words)
# Out:
# ['hello', 'everyone', '😊', 'name', 'misbah', 'khan', 'learning', 'natural', 'language', 'processing', 'nlp', 'love', 'machine', 'learning', 'machine', 'learning', 'machine', 'learning', 'contact', 'visit', 'information', 'completed', 'projects', 'scored', 'deep', 'learning', 'cats', 'running', 'jumping', 'playing', 'happily', 'gardens']

# %%
# stemming
from nltk.stem import PorterStemmer

stemmer = PorterStemmer()

stemmed_words = []

for word in filtered_words:
    stemmed_words.append(stemmer.stem(word))

print(stemmed_words)
# Out:
# ['hello', 'everyon', '😊', 'name', 'misbah', 'khan', 'learn', 'natur', 'languag', 'process', 'nlp', 'love', 'machin', 'learn', 'machin', 'learn', 'machin', 'learn', 'contact', 'visit', 'inform', 'complet', 'project', 'score', 'deep', 'learn', 'cat', 'run', 'jump', 'play', 'happili', 'garden']

# %%
# Lemmatization
from nltk.stem import PorterStemmer

stemmer = PorterStemmer()

stemmed_words = []

for word in filtered_words:
    stemmed_words.append(stemmer.stem(word))

print(stemmed_words)
# Out:
# ['hello', 'everyon', '😊', 'name', 'misbah', 'khan', 'learn', 'natur', 'languag', 'process', 'nlp', 'love', 'machin', 'learn', 'machin', 'learn', 'machin', 'learn', 'contact', 'visit', 'inform', 'complet', 'project', 'score', 'deep', 'learn', 'cat', 'run', 'jump', 'play', 'happili', 'garden']
